# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import psycopg2 
import sqlalchemy
import matplotlib as plt

# %matplotlib inline

# %%
c = psycopg2.connect(host='127.0.0.1', database='skye', user='smlong', password='tamere', sslmode='disable')

# %%
# %load_ext sql

# %%
cursorPsy= c.cursor(cursor_factory=psycopg2.extras.DictCursor)

# %%
cursorPsy.execute("SELECT max(\"TUYEAR\") FROM summary")

# %%
cursorPsy.fetchall()
# Out:
# [[2018]]

# %%
demographics = pd.read_sql_query('''SELECT * FROM summary WHERE \"TUYEAR\" BETWEEN 2008 AND 2018''', c)

# %%
demographics.dtypes
# Out:
# TUCASEID    float64
# GEMETSTA      int64
# GTMETSTA      int64
# PEEDUCA       int64
# PEHSPNON      int64
#              ...
# t500104       int64
# t500105       int64
# t500106       int64
# t500107       int64
# t509989       int64
# Length: 455, dtype: object

# %%
demographics.shape
# Out:
# (128229, 455)

# %%
demographics["personal_total"] = demographics.filter(regex='^t01', axis=1).sum(axis=1)

# %%
demographics
# Out:
#             TUCASEID  GEMETSTA  GTMETSTA  PEEDUCA  PEHSPNON  PTDTRACE  TEAGE  \
# 0       2.008010e+13        -1         2       36         1         1     55
# 1       2.008010e+13        -1         1       42         2         2     66
# 2       2.008010e+13        -1         1       34         2         1     80
# 3       2.008010e+13        -1         1       40         2         1     29
# 4       2.008010e+13        -1         2       39         2         1     34
# ...              ...       ...       ...      ...       ...       ...    ...
# 128224  2.018121e+13        -1         1       39         2         1     69
# 128225  2.018121e+13        -1         1       43         1         1     32
# 128226  2.018121e+13        -1         1       36         2         4     17
# 128227  2.018121e+13        -1         1       44         2         1     58
# 128228  2.018121e+13        -1         1       42         2         1     72
#
# ...

# %%
personal['personal_total'] = personal.sum(axis=1)
# Out:
# C:\Users\smlong\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
personal
# Out:
#         t010101  t010102  t010199  t010201  t010299  t010301  t010399  \
# 0           518        0        0       30        0        0        0
# 1          1420        0        0        0        0       15        0
# 2           360        0        0        0        0        0        0
# 3           600        0        0       90        0        0        0
# 4           600        0        0       60        0        0        0
# ...         ...      ...      ...      ...      ...      ...      ...
# 128224      411        0        0       71        0        2      120
# 128225      480        0        0       55        0        0        0
# 128226      720       55        0       90        0        0        0
# 128227      510        0        0       45        0        0        0
# 128228      540        0        0       75        0        0        0
#
#         t010401  t010499  t010501  t010599  t019999  personal_total
# ...
