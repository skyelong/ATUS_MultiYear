# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Income-and-Educational-Attainment" data-toc-modified-id="Income-and-Educational-Attainment-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Income and Educational Attainment</a></span><ul class="toc-item"><li><span><a href="#Basic-EDA" data-toc-modified-id="Basic-EDA-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Basic EDA</a></span></li></ul></li><li><span><a href="#Income-Brackets-by-Educational-Attainment" data-toc-modified-id="Income-Brackets-by-Educational-Attainment-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Income Brackets by Educational Attainment</a></span><ul class="toc-item"><li><span><a href="#Getting-the-x,y-values-as-{x:y}" data-toc-modified-id="Getting-the-x,y-values-as-{x:y}-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Getting the x,y values as {x:y}</a></span></li><li><span><a href="#Horizontal-bar-chart-code" data-toc-modified-id="Horizontal-bar-chart-code-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Horizontal bar chart code</a></span></li></ul></li><li><span><a href="#Percent-of-Income-Brackets-By-Educational-Attainment-(2008-2018)" data-toc-modified-id="Percent-of-Income-Brackets-By-Educational-Attainment-(2008-2018)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Percent of Income Brackets By Educational Attainment (2008-2018)</a></span></li><li><span><a href="#Change-in-income-Brackets-over-time-for-Advanced-Degree-Holders(Master's-+)" data-toc-modified-id="Change-in-income-Brackets-over-time-for-Advanced-Degree-Holders(Master's-+)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Change in income Brackets over time for Advanced Degree Holders(Master's +)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Education-combine---educ_comb" data-toc-modified-id="Education-combine---educ_comb-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>Education combine - educ_comb</a></span></li><li><span><a href="#Income-Combine-inc_comb" data-toc-modified-id="Income-Combine-inc_comb-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>Income Combine inc_comb</a></span></li><li><span><a href="#Getting-groups" data-toc-modified-id="Getting-groups-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>Getting groups</a></span></li></ul></li></ul></li><li><span><a href="#Income-Brackets-by-Year-and-Educational-Attainment" data-toc-modified-id="Income-Brackets-by-Year-and-Educational-Attainment-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Income Brackets by Year and Educational Attainment</a></span></li><li><span><a href="#Save-Point" data-toc-modified-id="Save-Point-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Save Point</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
sns.set()

# %% [markdown]
# # Income and Educational Attainment

# %% [markdown]
# ## Basic EDA

# %%
filename = 'edited.csv'
data = pd.read_csv(filename, index_col=0).reset_index(drop=True)

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0.1.1', 'case_id', 'education', 'age',
#        'employed', 'gender', 'spouse_empl', 'num_child', 'full_part_wrk',
#        'weekly_earn', 'weights', 'year', 'income', 'all_eth', 'educaton_text',
#        'income_text', 'gender_text', 'ethnicity_text', 'spouse_text',
#        'full_part_text'],
#       dtype='object')

# %%
data.education.value_counts()
# Out:
# 39    30355
# 43    25237
# 40    21258
# 38    17105
# 41    11641
# 44    11521
# 46     2291
# 45     1937
# Name: education, dtype: int64

# %%
#generate code maps for the education

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121345 entries, 0 to 121344
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0.1    121345 non-null  int64
#  1   Unnamed: 0.1.1  121345 non-null  int64
#  2   case_id         121345 non-null  float64
#  3   education       121345 non-null  int64
#  4   age             121345 non-null  int64
#  5   employed        121345 non-null  int64
#  6   gender          121345 non-null  int64
#  7   spouse_empl     121345 non-null  int64
#  8   num_child       121345 non-null  int64
#  9   full_part_wrk   121345 non-null  int64
#  10  weekly_earn     121345 non-null  int64
#  11  weights         121345 non-null  float64
#  12  year            121345 non-null  int64
#  13  income          121345 non-null  int64
#  14  all_eth         121345 non-null  int64
#  15  educaton_text   121345 non-null  object
#  16  income_text     121345 non-null  object
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
data.groupby(['education']).describe()
# Out:
#           Unnamed: 0.1                                                       \
#                  count          mean           std   min       25%      50%
# education
# 38             17105.0  56804.668752  34588.740320   8.0  26872.00  54961.0
# 39             30355.0  59511.388667  34745.549652   1.0  29665.50  58710.0
# 40             21258.0  59920.242685  35006.043811   2.0  29308.75  59370.0
# 41             11641.0  62268.259428  34892.479757  11.0  32037.00  63204.0
# 43             25237.0  62412.771169  35328.893438   9.0  31670.00  63494.0
# 44             11521.0  64498.251801  35076.176794   0.0  35077.00  66380.0
# 45              1937.0  60858.575632  35272.856069  35.0  29894.00  59969.0
# 46              2291.0  65213.411174  35323.615414  50.0  35362.00  67415.0
#
#                               Unnamed: 0.1.1                              \
#                 75%       max          count          mean           std
# education
# ...

# %% [markdown]
# # Income Brackets by Educational Attainment

# %% [markdown]
# ## Getting the x,y values as {x:y}

# %%
#Build the catagory lists for graphs and selecting data
edu_name = list(data.educaton_text.unique())
income_name = list(data.income_text.unique())
income_num = list(range(1,11))
edu_num = list(range(38,47))

# %%
#no 42 in list all associates were combined
edu_num.remove(42)

# %%
edu_num
# Out:
# [38, 39, 40, 41, 43, 44, 45, 46]

# %%
#lamely hand sort cat names
edu_name_sort = [
    'Less than High School', 'High School or GED', 'Some College',
    'Associates Degree', 'Bachelors', 'Masters', 'Professional_Deg', 'Doctoral'
]

# %%
income_name_sort = [
    '$0-$9,999',
    '$10,000 - $19,999',
    '$20,000 - $29,000',
    '$30,000 - $39,999',
    '$40,000 - $49,999',
    '$50,000 - $59,999',
    '$60,000 - $74,999',
    '$75,000 - $99,999',
    '$100,000 - $149,999',
    '$150000 and over',
]

# %%
#group by income and education
income_edu = data.groupby(['income', 'education'], as_index=False)

# %%
#group by income and education
income_edu = data.groupby(['income', 'education'], as_index=False)

# %%
less_high_1= len(income_edu.get_group((1,38)))

# %%
less_high_1
# Out:
# 2671

# %%
len(income_num)
# Out:
# 10

# %%
#get counts
key_name = []
values = []
for i in range(len(income_num)):
    key_name.append(income_name_sort[i])
    lst = []
    x = income_num[i]
    for i in range(len(edu_num)):
        y = edu_num[i]
        num = len((income_edu.get_group((x,y))))
        lst.append(num)
    values.append(lst)

# %%
income_edu_dict = {key_name[i]:values[i] for i in range(len(key_name))}

# %%
#get percents
key_name = []
values = []
for i in range(len(income_num)):
    key_name.append(income_name_sort[i])
    lst = []
    x = income_num[i]
    for i in range(len(edu_num)):
        y = edu_num[i]
        num = len((income_edu.get_group((x,y))))
        lst.append(num)
    values.append(lst)

# %%
values_per = [[round(number / sum(group) * 100, 2) for number in group]
              for group in values]

# %%
values_per
# Out:
# [[31.84, 32.12, 18.03, 6.62, 8.14, 2.34, 0.44, 0.48],
#  [27.31, 35.8, 18.01, 8.03, 7.87, 2.15, 0.47, 0.36],
#  [19.51, 36.15, 20.25, 9.26, 11.07, 3.0, 0.39, 0.37],
#  [15.21, 32.66, 20.88, 10.65, 14.85, 4.58, 0.6, 0.55],
#  [11.52, 28.98, 20.04, 11.76, 19.25, 6.94, 0.55, 0.95],
#  [10.43, 25.81, 19.58, 11.24, 22.32, 8.54, 0.91, 1.16],
#  [7.67, 22.28, 18.77, 11.43, 25.62, 11.27, 1.11, 1.85],
#  [7.45, 17.62, 16.08, 11.67, 28.98, 14.39, 1.47, 2.35],
#  [6.48, 11.89, 13.97, 8.98, 34.03, 18.38, 2.61, 3.65],
#  [6.8, 6.86, 9.41, 5.32, 34.01, 22.47, 7.81, 7.31]]

# %%
income_edu_dict_per = {
    key_name[i]: values_per[i]
    for i in range(len(key_name))
}

# %%
income_edu_dict_per
# Out:
# {'$0-$9,999': [31.84, 32.12, 18.03, 6.62, 8.14, 2.34, 0.44, 0.48],
#  '$10,000 - $19,999': [27.31, 35.8, 18.01, 8.03, 7.87, 2.15, 0.47, 0.36],
#  '$20,000 - $29,000': [19.51, 36.15, 20.25, 9.26, 11.07, 3.0, 0.39, 0.37],
#  '$30,000 - $39,999': [15.21, 32.66, 20.88, 10.65, 14.85, 4.58, 0.6, 0.55],
#  '$40,000 - $49,999': [11.52, 28.98, 20.04, 11.76, 19.25, 6.94, 0.55, 0.95],
#  '$50,000 - $59,999': [10.43, 25.81, 19.58, 11.24, 22.32, 8.54, 0.91, 1.16],
#  '$60,000 - $74,999': [7.67, 22.28, 18.77, 11.43, 25.62, 11.27, 1.11, 1.85],
#  '$75,000 - $99,999': [7.45, 17.62, 16.08, 11.67, 28.98, 14.39, 1.47, 2.35],
#  '$100,000 - $149,999': [6.48, 11.89, 13.97, 8.98, 34.03, 18.38, 2.61, 3.65],
#  '$150000 and over': [6.8, 6.86, 9.41, 5.32, 34.01, 22.47, 7.81, 7.31]}

# %% [markdown]
# ## Horizontal bar chart code

# %% [markdown]
# [reference](https://matplotlib.org/gallery/lines_bars_and_markers/horizontal_barchart_distribution.html#sphx-glr-gallery-lines-bars-and-markers-horizontal-barchart-distribution-py)

# %%
def stacked_hor_bar(results, category_names):
    """
    Parameters
    ----------
    results : dict
        A mapping from question labels to a list of answers per category.
        It is assumed all lists contain the same number of entries and that
        it matches the length of *category_names*.
    category_names : list of str
        The category labels.
    """
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.get_cmap('RdYlGn')(
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(29, 18))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_yticklabels(labels, fontsize = 20)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        ax.barh(labels, widths, left=starts, height=0.8,
                label=colname, color=color)
        xcenters = starts + widths / 2

        r, g, b, _ = color
        text_color = 'linen' if r * g * b < 0.2 else 'black'
        for y, (x, c) in enumerate(zip(xcenters, widths)):
            ax.text(x, y, str(int(c)), ha='center', va='center',
                    color=text_color, fontsize=20)
    ax.legend(ncol=len(category_names),
              loc='upper left', fontsize='x-large')
    plt.savefig('income_edu', dpi=300)

    return fig, ax

# %% [markdown]
# # Percent of Income Brackets By Educational Attainment (2008-2018)

# %%
stacked_hor_bar(income_edu_dict_per,edu_name_sort)
# Out:
# (<Figure size 2088x1296 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1da5d5df108>)

# %% [markdown]
# # Change in income Brackets over time for Advanced Degree Holders(Master's +)

# %% [markdown]
# ### Education combine - educ_comb

# %%
income_year = data.groupby(['year', 'income'], as_index=False)

# %%
income_year_3 = data.groupby(['year', 'income', 'education'], as_index=False)

# %%
highest_1= income_year.get_group((2008,1))

# %%
highest_1_edu = highest_1.groupby(['education'])

# %%
highest_1_edu.size()

# %% [markdown]
# To make the graph cleaner, I am grouping education into three categories,
# 1-No College | 38,39,40
# 2 -College Degree | 41,43 (assoc & Bach)
# 3 - Higher Degree | 44,45,46 (masters, proff, phd)

# %%
#combine the education values
data['educ_comb'] = data['education'].apply(lambda x: 1 if x <=40 else(2 if (x == 41 or x ==43) else 3))

# %%
data.educ_comb.value_counts()
# Out:
# 1    68718
# 2    36878
# 3    15749
# Name: educ_comb, dtype: int64

# %% [markdown]
# ### Income Combine inc_comb

# %% [markdown]
# Combined income levels:
# low | 1-5 | $0-49999
#
# High | 6-10 | 50000-150000

# %%
plt.hist(data["income"], bins=10)
# Out:
# (array([ 8390., 13740., 13945., 13771., 10271.,  9979., 12271., 14401.,
#         13773., 10804.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 10 Patch objects>)

# %%
#combine the income values
data['inc_comb'] = data['income'].apply(lambda x: 1 if x <=5 else 2)

# %%
data.inc_comb.value_counts()
# Out:
# 2    61228
# 1    60117
# Name: inc_comb, dtype: int64

# %% [markdown]
# ### Getting groups

# %%
year_inc_edu = data[['year', 'inc_comb', 'educ_comb']]

# %%
by_year_inc = year_inc_edu.groupby(['year', 'inc_comb', 'educ_comb'], as_index=False)

# %%
by_year_inc.get_group((2008,1,1))
# Out:
#       year  inc_comb  educ_comb
# 1     2008         1          1
# 2     2008         1          1
# 3     2008         1          1
# 4     2008         1          1
# 5     2008         1          1
# 6     2008         1          1
# 7     2008         1          1
# 8     2008         1          1
# 14    2008         1          1
# 15    2008         1          1
# 19    2008         1          1
# 22    2008         1          1
# 28    2008         1          1
# 29    2008         1          1
# 32    2008         1          1
# 38    2008         1          1
# 41    2008         1          1
# 42    2008         1          1
# 44    2008         1          1
# 45    2008         1          1
# 46    2008         1          1
# 47    2008         1          1
# 48    2008         1          1
# 54    2008         1          1
# 57    2008         1          1
# 65    2008         1          1
# 66    2008         1          1
# 67    2008         1          1
# ...

# %%
#get percents
inc_num_com = [1,2]*11
edu_num_com = [1,2,3]
years = [2008,2008,2009,2009,2010,2010,2011,2011,2012,2012,2013,2013,2014,2014,2015,2015,2016,2016,2017,2017,2018,2018]
key_name_2 = []
income_dict = []
values_2 = []
for i in range(len(years)):
    lst = []
    x = years[i]
    y = inc_num_com[i]
    #name = str(x)+"_" + str(y)
    key_name_2.append(x)
    income_dict.append(y)
    for i in range(len(edu_num_com)):
        z = edu_num_com[i]
        num = len((by_year_inc.get_group((x,y,z))))
        print(x,y,z)
        lst.append(num)
    values_2.append(lst)
# Out:
# 2008 1 1
# 2008 1 2
# 2008 1 3
# 2008 2 1
# 2008 2 2
# 2008 2 3
# 2009 1 1
# 2009 1 2
# 2009 1 3
# 2009 2 1
# 2009 2 2
# 2009 2 3
# 2010 1 1
# 2010 1 2
# 2010 1 3
# 2010 2 1
# 2010 2 2
# 2010 2 3
# 2011 1 1
# 2011 1 2
# 2011 1 3
# 2011 2 1
# 2011 2 2
# 2011 2 3
# 2012 1 1
# 2012 1 2
# 2012 1 3
# 2012 2 1
# 2012 2 2
# 2012 2 3
# 2013 1 1
# 2013 1 2
# 2013 1 3
# 2013 2 1
# 2013 2 2
# 2013 2 3
# 2014 1 1
# 2014 1 2
# 2014 1 3
# 2014 2 1
# 2014 2 2
# 2014 2 3
# 2015 1 1
# 2015 1 2
# 2015 1 3
# 2015 2 1
# 2015 2 2
# 2015 2 3
# 2016 1 1
# 2016 1 2
# 2016 1 3
# 2016 2 1
# 2016 2 2
# 2016 2 3
# 2017 1 1
# 2017 1 2
# 2017 1 3
# 2017 2 1
# 2017 2 2
# 2017 2 3
# 2018 1 1
# 2018 1 2
# 2018 1 3
# 2018 2 1
# 2018 2 2
# 2018 2 3

# %%
values_2
# Out:
# [[3155, 814, 164],
#  [1776, 1525, 787],
#  [4337, 1157, 252],
#  [2346, 2183, 1030],
#  [4968, 1308, 277],
#  [2595, 2366, 1192],
#  [4959, 1340, 310],
#  [2491, 2183, 1196],
#  [4787, 1386, 303],
#  [2443, 2281, 1243],
#  [4253, 1248, 276],
#  [2204, 2224, 1180],
#  [4192, 1291, 303],
#  [2241, 2316, 1249],
#  [3780, 1168, 244],
#  [2197, 2267, 1249],
#  [3583, 1138, 268],
#  [2140, 2139, 1225],
#  [3336, 1081, 248],
#  [2062, 2247, 1249],
#  [2947, 1024, 220],
#  [1926, 2192, 1284]]

# %%
len(key_name_2)
# Out:
# 22

# %%
len(income_dict)
# Out:
# 22

# %%
by_year_inc.get_group((2008,1,3)).count()
# Out:
# year         164
# inc_comb     164
# educ_comb    164
# dtype: int64

# %%
values_per_2 = [[round(number / sum(group) * 100, 2) for number in group]
              for group in values_2]

# %%
values_per_2
# Out:
# [[76.34, 19.7, 3.97],
#  [43.44, 37.3, 19.25],
#  [75.48, 20.14, 4.39],
#  [42.2, 39.27, 18.53],
#  [75.81, 19.96, 4.23],
#  [42.17, 38.45, 19.37],
#  [75.03, 20.28, 4.69],
#  [42.44, 37.19, 20.37],
#  [73.92, 21.4, 4.68],
#  [40.94, 38.23, 20.83],
#  [73.62, 21.6, 4.78],
#  [39.3, 39.66, 21.04],
#  [72.45, 22.31, 5.24],
#  [38.6, 39.89, 21.51],
#  [72.8, 22.5, 4.7],
#  [38.46, 39.68, 21.86],
#  [71.82, 22.81, 5.37],
#  [38.88, 38.86, 22.26],
#  [71.51, 23.17, 5.32],
#  [37.1, 40.43, 22.47],
#  [70.32, 24.43, 5.25],
#  [35.65, 40.58, 23.77]]

# %%
year_inc_edu_dict_per = {
    key_name_2[i]: values_per_2[i]
    for i in range(len(key_name_2))
}

# %%
len(key_name_2)
# Out:
# 22

# %%
df_year_inc_edu = pd.DataFrame.from_dict(year_inc_edu_dict_per, orient='index', columns=["edu_1", "edu_2", "edu_3"]).reset_index()

# %%
low_earn = df_year_inc_edu.iloc[::2]

# %%
high_earn = df_year_inc_edu.iloc[1::2]

# %%
high_earn.reset_index(drop=True, inplace=True)

# %%
high_earn
# Out:
#      index  edu_1  edu_2  edu_3
# 0   2008_2  43.44  37.30  19.25
# 1   2009_2  42.20  39.27  18.53
# 2   2010_2  42.17  38.45  19.37
# 3   2011_2  42.44  37.19  20.37
# 4   2012_2  40.94  38.23  20.83
# 5   2013_2  39.30  39.66  21.04
# 6   2014_2  38.60  39.89  21.51
# 7   2015_2  38.46  39.68  21.86
# 8   2016_2  38.88  38.86  22.26
# 9   2017_2  37.10  40.43  22.47
# 10  2018_2  35.65  40.58  23.77

# %%
low_earn.reset_index(drop=True, inplace=True)

# %%
low_earn
# Out:
#      index  edu_1  edu_2  edu_3
# 0   2008_1  76.34  19.70   3.97
# 2   2009_1  75.48  20.14   4.39
# 4   2010_1  75.81  19.96   4.23
# 6   2011_1  75.03  20.28   4.69
# 8   2012_1  73.92  21.40   4.68
# 10  2013_1  73.62  21.60   4.78
# 12  2014_1  72.45  22.31   5.24
# 14  2015_1  72.80  22.50   4.70
# 16  2016_1  71.82  22.81   5.37
# 18  2017_1  71.51  23.17   5.32
# 20  2018_1  70.32  24.43   5.25

# %%
low_earn.to_csv('low.csv')

# %% [markdown]
# # Income Brackets by Year and Educational Attainment

# %%
fig, ax = plt.subplots(figsize=(15,11))
low_earn[['edu_1','edu_2', 'edu_3']].plot.bar(stacked=True, width=0.2, position=-0.25, colormap="summer", ax=ax, alpha=0.7)
high_earn[['edu_1', 'edu_2', 'edu_3']].plot.bar(stacked=True, width=0.2, position=-1.75, colormap="summer", ax = ax, alpha=0.7)
ax.legend(ncol=6, loc='upper left', fontsize='large')
plt.show()

# %% [markdown]
# # Save Point

# %%
data.to_csv('combined_edu_income.csv')
